# %%
# import tweepy
import tweepy as tw
# your Twitter API key and API secret
my_api_key = "vYnTjxjFWL471STe2HW2dERiN"
my_api_secret = "oTsvu8BI2rwxvzTge0xIreCTmcJJxxSESk7XINbQHvgsiibocG"
# authenticate
auth = tw.OAuthHandler(my_api_key, my_api_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# setting up a search query
search_query = "#airtel -filter:retweets"

# %%
# get tweets from the API
tweets = tw.Cursor(api.search,
              q=search_query,
              lang="en",
              since="2019-01-01").items(500)
# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)
    
print("Total Tweets fetched:", len(tweets_copy))
# Out:
# Total Tweets fetched: 500

# %%
import pandas as pd
# intialize the dataframe
tweets_df = pd.DataFrame()
# populate the dataframe
for tweet in tweets_copy:
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source}))
    tweets_df = tweets_df.reset_index(drop=True)
# show the dataframe
tweets_df.head()
# Out:
#                                   user_name                   user_location  \
# 0                                Aravindh S               Tamil Nadu, India
# 1                            Gbest Bulk SMS                   Abuja Nigeria
# 2                       Kalyanashis Mahanty  Barabhum ,  West Bengal, India
# 3  Network Palava - Free, Cheap Data Daily.                  Lagos, Nigeria
# 4                                 JayRoy 🇮🇳
#
#                                     user_description  user_verified  \
# 0                         Nemophilist 🌎 90's KID 😉 😜          False
# 1  Providers of Bulk SMS | Data Bundle | Airtime ...          False
# 2  School teacher by profession and I am everythi...          False
# 3  Get Cheap, Free Browsing Solutions at https://...          False
# 4         Proud Indian \n\n(RT's r not endorsements)          False
#
#                  date                                               text  \
# 0 2022-03-14 12:38:42  And I am hearing new stories that within a sma...
# 1 2022-03-14 12:21:29  Do U have excess Airtime in ur line and will l...
# 2 2022-03-14 12:05:51  @airtelindia @Airtel_Presence bye bye for now....
# 3 2022-03-14 11:59:45  Working NapsternetV Configuration Files Downlo...
# 4 2022-03-14 11:55:01  @airtelnews @airtelindia @Airtel_Presence @air...
#
#   hashtags               source
# 0     None   Twitter for iPhone
# 1     None  Twitter for Android
# 2     None  Twitter for Android
# 3    [mtn]    Revive Social App
# 4     None      Twitter Web App

# %%
tweets_df.shape
# Out:
# (500, 8)

# %%
tweets_df
# Out:
#                                     user_name                   user_location  \
# 0                                  Aravindh S               Tamil Nadu, India
# 1                              Gbest Bulk SMS                   Abuja Nigeria
# 2                         Kalyanashis Mahanty  Barabhum ,  West Bengal, India
# 3    Network Palava - Free, Cheap Data Daily.                  Lagos, Nigeria
# 4                                   JayRoy 🇮🇳
# ..                                        ...                             ...
# 495                               Akshay Sood                      Hoshiarpur
# 496                           The Rewind Guys                           India
# 497                              Telecom TALK                           India
# 498                               Tarun Tyagi                Ghaziabad, India
# 499                       Developing Telecoms                          London
#
#                                       user_description  user_verified  \
# 0                           Nemophilist 🌎 90's KID 😉 😜          False
# 1    Providers of Bulk SMS | Data Bundle | Airtime ...          False
# 2    School teacher by profession and I am everythi...          False
# 3    Get Cheap, Free Browsing Solutions at https://...          False
# 4           Proud Indian \n\n(RT's r not endorsements)          False
# ..                                                 ...            ...
# 495                                                             False
# 496  Tech News | Quick Thoughts | Comparisons | Bas...          False
# 497  #Telecom #5G #Mobile #DTH\n \nPR Mails: news a...           True
# 498  Author by Choice, Engineer by Profession and M...          False
# 499  Developing Telecoms is the international telec...          False
#
#                    date                                               text  \
# 0   2022-03-14 12:38:42  And I am hearing new stories that within a sma...
# 1   2022-03-14 12:21:29  Do U have excess Airtime in ur line and will l...
# 2   2022-03-14 12:05:51  @airtelindia @Airtel_Presence bye bye for now....
# 3   2022-03-14 11:59:45  Working NapsternetV Configuration Files Downlo...
# 4   2022-03-14 11:55:01  @airtelnews @airtelindia @Airtel_Presence @air...
# ..                  ...                                                ...
# 495 2022-03-08 06:35:45  @Airtel_Presence @airtelindia  My Airtel Xtrem...
# 496 2022-03-08 06:30:03  Along with the credit card, both the companies...
# 497 2022-03-08 06:23:11  Satcom: Jio, Airtel Entry Doesn’t Mean Low Pri...
# 498 2022-03-08 06:02:49  All #Airtel Internet Connections including Mob...
# 499 2022-03-08 06:00:03  Bharti Airtel, Axis Bank announce strategic pa...
#
#                                               hashtags  \
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3                                                [mtn]
# 4                                                 None
# ..                                                 ...
# 495                                               None
# 496                                               None
# 497                              [Satcom, jio, Airtel]
# 498                                           [Airtel]
# 499  [India, BhartiAirtel, Airtel, ICT, CyberSecuri...
#
#                              source
# 0                Twitter for iPhone
# 1               Twitter for Android
# 2               Twitter for Android
# 3                 Revive Social App
# 4                   Twitter Web App
# ..                              ...
# 495                 Twitter Web App
# 496                  Hootsuite Inc.
# 497                 Twitter Web App
# 498                 Twitter Web App
# 499  Developing Telecoms Auto Tweet
#
# [500 rows x 8 columns]

# %%
tweets_df.to_csv(r'/content/drive/MyDrive/college/sem7/FYP/tweets_dataset.csv')
